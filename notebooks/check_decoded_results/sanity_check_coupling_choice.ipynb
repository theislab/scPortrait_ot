# %%
from hydra import initialize, compose
from omegaconf import OmegaConf
from pathlib import Path

import sys 
sys.path.insert(0, "../../src")

import numpy as np
import scipy.spatial.distance as spd
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns

from dataloader import SingleCellAndCodexDataset 
from model import FlowMatchingModelWrapper
from torch.utils.data import random_split
import torch
from torch.utils.data import Dataset, DataLoader
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning import Trainer

plt.rcParams['figure.figsize'] = (3, 3)

# %%
adata_codex = sc.read_h5ad("/nfs/staff-hdd/pala/scportrait/data/codex/cellfeaturization_results_healthy_processed.h5ad")
adata_single_cell = sc.read_h5ad("/nfs/staff-hdd/pala/scportrait/data/scrnaseq/sce_converted_processed_discovery.h5ad")

# %%
(adata_codex.X[:, 0]==0).any()
# Out:
# np.False_

# %%
adata_single_cell.X
# Out:
# array([[2.87997273, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [5.13941058, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [2.2890183 , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [1.95297184, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [2.53255074, 0.        , 1.78594984, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]], shape=(263286, 55))

# %%
with initialize(config_path="../../configs/"):
    # Step 2: Compose the configuration
    config_dict = compose(config_name="train")  # replace 'config' with your actual config name
# Out:
# /tmp/ipykernel_2617285/4061682399.py:1: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize(config_path="../../configs/"):

# %%
dataset = SingleCellAndCodexDataset(config_dict.datamodule.rna_adata_path, 
                                        config_dict.datamodule.codex_adata_path, 
                                        config_dict.datamodule.label_columns, 
                                        config_dict.datamodule.obsm_key_rna, 
                                        config_dict.datamodule.obsm_key_codex)

# %%
dataloader = torch.utils.data.DataLoader(dataset,
                                            batch_size=64,
                                            shuffle=True,
                                            num_workers=4)
# Out:
# /nfs/staff-ssd/pala/miniconda3/envs/sc_exp_design/lib/python3.10/site-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
distances = {}
for codex_cl in np.unique(adata_codex.obs.shared_leiden_cluster_id):
    distances[codex_cl] = {"RNA cell type": [], "Distance": []}
    for rna_cl in np.unique(adata_single_cell.obs.annotation_figure_1):
        distances[codex_cl]["RNA cell type"].append(rna_cl)
        X_codex = adata_codex[adata_codex.obs.shared_leiden_cluster_id==codex_cl].X
        X_rna = adata_single_cell[adata_single_cell.obs.annotation_figure_1==rna_cl].X
        ave_dist = np.matmul(X_codex, X_rna.T).mean()
        distances[codex_cl]["Distance"].append(ave_dist)

# %%
distances
# Out:
# {'0': {'RNA cell type': ['Activated NBC',
#    'CD4 T',
#    'CD8 T',
#    'DC',
#    'DN',
#    'FDC',
#    'GCBC',
#    'Granulocytes',
#    'ILC',
#    'MBC',
#    'Mast',
#    'Mono/Macro',
#    'NBC',
#    'NK',
#    'Naive CD4 T',
#    'Naive CD8 T',
#    'PC',
#    'PDC',
#    'cycling FDC',
#    'cycling T',
#    'cycling myeloid',
#    'epithelial',
#    'preB/T'],
#   'Distance': [np.float64(0.14369722559737264),
#    np.float64(0.22015643949299407),
#    np.float64(0.19977377183045825),
#    np.float64(0.15253882771839344),
#    np.float64(0.20746984565572535),
#    np.float64(0.11107734441493625),
#    np.float64(0.14828930087261227),
#    np.float64(0.0950939859959813),
#    np.float64(0.18350662453760377),
#    np.float64(0.1690949386629015),
#    np.float64(0.11534250118241929),
#    np.float64(0.12628834678898987),
#    np.float64(0.1482847341235781),
#    np.float64(0.1754566103955214),
#    np.float64(0.18331112641057465),
#    np.float64(0.16936823834708506),
#    np.float64(0.06547655611748164),
#    np.float64(0.13784242154134294),
#    np.float64(0.09850128656680325),
#    np.float64(0.2113564251985686),
#    np.float64(0.13771549036717512),
#    np.float64(0.04249836933841632),
#    np.float64(0.11360291272125721)]},
#  '1': {'RNA cell type': ['Activated NBC',
#    'CD4 T',
#    'CD8 T',
#    'DC',
#    'DN',
#    'FDC',
#    'GCBC',
#    'Granulocytes',
#    'ILC',
#    'MBC',
#    'Mast',
#    'Mono/Macro',
#    'NBC',
#    'NK',
#    'Naive CD4 T',
#    'Naive CD8 T',
#    'PC',
#    'PDC',
#    'cycling FDC',
#    'cycling T',
#    'cycling myeloid',
#    'epithelial',
#    'preB/T'],
#   'Distance': [np.float64(0
{'RNA cell type': ['Activated NBC',
#    'CD4 T',
#    'CD8 T',
#    'DC',
#    'DN',
#    'FDC',
#    'GCBC',
#    'Granulocytes',
#    'ILC',
#    'MBC',
#    'Mast',
#    'Mono/Macro',
#    'NBC',
#    'NK',
#    'Naive CD4 T',
#    'Naive CD8 T',
#    'PC',
#    'PDC',
#    'cycling FDC',
#    'cycling T',
#    'cycling myeloid',
#    'epithelial',
#    'preB/T'],
#   'Distance': [np.float64(0.16993174554033114),
#    np.float64(0.1427056402740456),
#    np.float64(0.13630007109623227),
#    np.float64(0.12874353676757594),
#    np.float64(0.14493339826701987),
#    np.float64(0.12870613865430275),
#    np.float64(0.1800969103773149),
#    np.float64(0.09102913217451634),
#    np.float64(0.14602971668493628),
#    np.float64(0.18926222415984964),
#    np.float64(0.10441519456638487),
#    np.float64(0.10984965457994264),
#    np.float64(0.17402959377929375),
#    np.float64(0.1370173258222862),
#    np.float64(0.11423781684731396),
#    np.float64(0.1008220050184567),
#    np.float64(0.07294710847943699),
#    np.float64(0.10342033496809977),
#    np.float64(0.12168028385770102),
#    np.float64(0.14666529734387948),
#    np.float64(0.1278272359692994),
#    np.float64(0.05284965889823636),
#    np.float64(0.11387794568461147)]},
#  '8': {'RNA cell type': ['Activated NBC',
#    'CD4 T',
#    'CD8 T',
#    'DC',
#    'DN',
#    'FDC',
#    'GCBC',
#    'Granulocytes',
#    'ILC',
#    'MBC',
#    'Mast',
#    'Mono/Macro',
#    'NBC',
#    'NK',
#    'Naive CD4 T',
#    'Naive CD8 T',
#    'PC',
#    'PDC',
#    'cycling FDC',
#    'cycling T',
#    'cycling myeloid',
#    'epithelial',
#    'preB/T'],
#   'Distance': [np.float64(0.21264260887967787),
#    np.float64(0.1681588625428473),
#    np.float64(0.16035595019626497),
#    np.float64(0.14656390391076712),
#    np.float64(0.16686058795782802),
#    np.float64(0.1307371127960194),
#    np.float64(0.21738330868622746),
#    np.float64(0.10340588626798763),
#    np.float64(0.1593347760358157),
#    np.float64(0.23162885457819796),
#    np.float64(0.10523718623645428),
#    np.float64(0.1240087636389317),
#    np.float64(0.2219657962610098),
#    np.float64(0.15208502160721252),
#    np.float64(0.13700016062240686),
#    np.float64(0.12347699520430896),
#    np.float64(0.0829840424434451),
#    np.float64(0.11373125227723473),
#    np.float64(0.13549987664384675),
#    np.float64(0.16458849432201061),
#    np.float64(0.1471028651065133),
#    np.float64(0.05066864324225561),
#    np.float64(0.13798593050932453)]},
#  '9': {'RNA cell type': ['Activated NBC',
#    'CD4 T',
#    'CD8 T',
#    'DC',
#    'DN',
#    'FDC',
#    'GCBC',
#    'Granulocytes',
#    'ILC',
#    'MBC',
#    'Mast',
#    'Mono/Macro',
#    'NBC',
#    'NK',
#    'Naive CD4 T',
#    'Naive CD8 T',
#    'PC',
#    'PDC',
#    'cycling FDC',
#    'cycling T',
#    'cycling myeloid',
#    'epithelial',
#    'preB/T'],
#   'Distance': [np.float64(0.14971322249605276),
#    np.float64(0.16885076380685918),
#    np.float64(0.15539662475822436),
#    np.float64(0.13622645583104248),
#    np.float64(0.18369565127131937),
#    np.float64(0.11907401794559129),
#    np.float64(0.17802073612942085),
#    np.float64(0.09042198086664403),
#    np.float64(0.16205341882956248),
#    np.float64(0.1732084373859673),
#    np.float64(0.10717054459419355),
#    np.float64(0.11712499050927835),
#    np.float64(0.1561480453119033),
#    np.float64(0.15412952363008503),
#    np.float64(0.13721539339985248),
#    np.float64(0.12191269056059463),
#    np.float64(0.0889670606796696),
#    np.float64(0.11813993755074238),
#    np.float64(0.10932770724306684),
#    np.float64(0.17216027357089703),
#    np.float64(0.13282261688850142),
#    np.float64(0.04427265437823154),
#    np.float64(0.14272360289393368)]}}
